# %% [markdown]
# ## 1 - Qual o Problema do Negócio

# %% [markdown]
# http://www.kaggle.com/mlg-ulb/creditcardfraud
#
#
#
# *   Os conjuntos de dados contêm **transações** feitas por cartões de crédito em setembro de 2013 por titulares de cartões europeis.
#
# *   Este conjunto de dados apresenta as transações que ocorreram em dois dias, onde **temos 492 fraudes em 284.807 transações**. O conjunto de dados é altamente desequilibrado, a classe prosivida (fraudes) é responsável por 0,172% de todas as transações.
#
# *   Ele contém apenas variáveis de entrada numéricas que são o resultado de uma **transformação PCA**. Infelizmente, devido a questãos de **confidencialidade**, não podemos fornecer os recursos originais e mais informações básicas sobre os dados. Os recursos V1, V2, ... V28 são os componentes principais obtidos com o **PCA**, os únicos recursos que não foram transformados com o PCA são 'Tempo" e 'Quantidade".
#
# *   O recurso 'Tempo' contém os segundos decorridos entre cada transação e a primeira transação no conjunto de dados. O recurso 'Amoun' é o Total $ da transação, esse recurso pode ser usado, por exemplo, para estudos diversos.
#
# *   O recurso **'Classe' é a variável TARGET**e assume o valor 1 em caso de fraude e 0 caso contrário

# %% [markdown]
# ## 2 - Análise Exploratória dos Dados

# %%
# Bibliotecas
import pandas as pd
from pycaret.classification import *

# %%
# Carga de dados
origem = './creditcard.csv'
df = pd.read_csv(origem, low_memory = False)

# %%
# Visualizando o DataFrame
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
# Verificação de missing
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Verificação das informações
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %% [markdown]
# ## 3 - Pré-Processamento dos Dados

# %% [markdown]
# *   O conjunto de dados não possui dados faltantes
#
# *   Todas as variáveis estão limpas e normalizadas
#
# *   Não há necessidade de aplicar a etapa referente a Engenharia de Features
#
# *   A separação do conjunto X e y será feita na etapa de construção do Modelo

# %% [markdown]
# # 4 - Construção do Modelo

# %% [markdown]
# *   Essa etapa visa a escolha do Modelo ideal para representar a solução para o negócio.
#
# *   O conjunto de dados será submetido na função de auto machine learning, onde vários modelos com várias combinações serão submetidos e apresentados, em ordem de resultados.
#
# *   Serão escolhidos os melhores modelos para criar uma combinação **"BAGGING"** que representará a média pelos votos
#
# *   Serão removidos multicolinearidade e variáveis com baixa covariancia.
#
# *   A seleção de features será realizada de forma automática

# %%
# Criando o setup de classificação
classificacao = setup(
    data = df,
    target = 'Class',
    ignore_low_variance = True,
    remove_multicollinearity = True,
    multicollinearity_threshold = 0.95,
    n_jobs = 2,
    fix_imbalance = True
)
# Out:
# <style type="text/css">
# #T_266e5_row36_col1, #T_266e5_row42_col1, #T_266e5_row44_col1, #T_266e5_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_266e5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_266e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_266e5_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_266e5_row0_col1" class="data row0 col1" >2456</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_266e5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_266e5_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_266e5_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_266e5_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_266e5_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_266e5_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_266e5_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_266e5_row4_col1" class="data row4 col1" >(284807, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_266e5_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_266e5_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_266e5_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_266e5_row6_col1" class="data row6 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_266e5_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_266e5_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_266e5_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_266e5_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_266e5_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_266e5_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_266e5_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_266e5_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_266e5_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_266e5_row11_col1" class="data row11 col1" >(199364, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_266e5_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_266e5_row12_col1" class="data row12 col1" >(85443, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_266e5_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_266e5_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_266e5_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_266e5_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_266e5_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_266e5_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_266e5_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_266e5_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_266e5_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_266e5_row17_col1" class="data row17 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_266e5_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_266e5_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_266e5_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_266e5_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_266e5_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_266e5_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_266e5_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_266e5_row21_col1" class="data row21 col1" >d474</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_266e5_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_266e5_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_266e5_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_266e5_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_266e5_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_266e5_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_266e5_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_266e5_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_266e5_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_266e5_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_266e5_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_266e5_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_266e5_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_266e5_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_266e5_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_266e5_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_266e5_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_266e5_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_266e5_

# %%
# Comparação de modelos para escolha
avaliacao = compare_models(sort = 'F1')
# Out:
# <style type="text/css">
# #T_a803c_ th {
#   text-align: left;
# }
# #T_a803c_row0_col0, #T_a803c_row0_col2, #T_a803c_row0_col3, #T_a803c_row1_col0, #T_a803c_row1_col1, #T_a803c_row1_col2, #T_a803c_row1_col3, #T_a803c_row1_col4, #T_a803c_row1_col5, #T_a803c_row1_col6, #T_a803c_row1_col7, #T_a803c_row2_col0, #T_a803c_row2_col1, #T_a803c_row2_col2, #T_a803c_row2_col3, #T_a803c_row2_col4, #T_a803c_row2_col5, #T_a803c_row2_col6, #T_a803c_row2_col7, #T_a803c_row3_col0, #T_a803c_row3_col1, #T_a803c_row3_col2, #T_a803c_row3_col3, #T_a803c_row3_col4, #T_a803c_row3_col5, #T_a803c_row3_col6, #T_a803c_row3_col7, #T_a803c_row4_col0, #T_a803c_row4_col1, #T_a803c_row4_col3, #T_a803c_row4_col4, #T_a803c_row4_col5, #T_a803c_row4_col6, #T_a803c_row4_col7, #T_a803c_row5_col0, #T_a803c_row5_col1, #T_a803c_row5_col2, #T_a803c_row5_col3, #T_a803c_row5_col4, #T_a803c_row5_col5, #T_a803c_row5_col6, #T_a803c_row5_col7, #T_a803c_row6_col0, #T_a803c_row6_col1, #T_a803c_row6_col2, #T_a803c_row6_col3, #T_a803c_row6_col4, #T_a803c_row6_col5, #T_a803c_row6_col6, #T_a803c_row6_col7, #T_a803c_row7_col0, #T_a803c_row7_col1, #T_a803c_row7_col2, #T_a803c_row7_col3, #T_a803c_row7_col4, #T_a803c_row7_col5, #T_a803c_row7_col6, #T_a803c_row7_col7, #T_a803c_row8_col0, #T_a803c_row8_col1, #T_a803c_row8_col2, #T_a803c_row8_col3, #T_a803c_row8_col4, #T_a803c_row8_col5, #T_a803c_row8_col6, #T_a803c_row8_col7, #T_a803c_row9_col0, #T_a803c_row9_col1, #T_a803c_row9_col2, #T_a803c_row9_col4, #T_a803c_row9_col5, #T_a803c_row9_col6, #T_a803c_row9_col7, #T_a803c_row10_col0, #T_a803c_row10_col1, #T_a803c_row10_col2, #T_a803c_row10_col3, #T_a803c_row10_col4, #T_a803c_row10_col5, #T_a803c_row10_col6, #T_a803c_row10_col7, #T_a803c_row11_col0, #T_a803c_row11_col1, #T_a803c_row11_col2, #T_a803c_row11_col3, #T_a803c_row11_col4, #T_a803c_row11_col5, #T_a803c_row11_col6, #T_a803c_row11_col7, #T_a803c_row12_col0, #T_a803c_row12_col1, #T_a803c_row12_col2, #T_a803c_row12_col3, #T_a803c_row12_col4, #T_a803c_row12_col5, #T_a803c_row12_col6, #T_a803c_row12_col7, #T_a803c_row13_col0, #T_a803c_row13_col1, #T_a803c_row13_col2, #T_a803c_row13_col3, #T_a803c_row13_col4, #T_a803c_row13_col5, #T_a803c_row13_col6, #T_a803c_row13_col7 {
#   text-align: left;
# }
# #T_a803c_row0_col1, #T_a803c_row0_col4, #T_a803c_row0_col5, #T_a803c_row0_col6, #T_a803c_row0_col7, #T_a803c_row4_col2, #T_a803c_row9_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a803c_row0_col8, #T_a803c_row1_col8, #T_a803c_row2_col8, #T_a803c_row3_col8, #T_a803c_row4_col8, #T_a803c_row5_col8, #T_a803c_row6_col8, #T_a803c_row7_col8, #T_a803c_row8_col8, #T_a803c_row9_col8, #T_a803c_row10_col8, #T_a803c_row11_col8, #T_a803c_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a803c_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a803c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a803c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_a803c_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_a803c_row0_col1" class="data row0 col1" >0.9996</td>
#       <td id="T_a803c_row0_col2" class="data row0 col2" >0.9792</td>
#       <td id="T_a803c_row0_col3" class="data row0 col3" >0.8353</td>
#       <td id="T_a803c_row0_col4" class="data row0 col4" >0.9136</td>
#       <td id="T_a803c_row0_col5" class="data row0 col5" >0.8717</td>
#       <td id="T_a803c_row0_col6" class="data row0 col6" >0.8715</td>
#       <td id="T_a803c_row0_col7" class="data row0 col7" >0.8729</td>
#       <td id="T_a803c_row0_col8" class="data row0 col8" >11.7400</td>
#     </tr>
#     <tr>
#       <th id="T_a803c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_a803c_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_a803c_row1_col1" class="data row1 col1" >0.9995</td>
#       <td id="T_a803c_row1_col2" class="data row1 col2" >0.9736</td>
#       <td id="T_a803c_row1_col3" class="data row1 col3" >0.8265</td>
#       <td id="T_a803c_row1_col4" class="data row1 col4" >0.8874</td>
#       <td id="T_a803c_row1_col5" class="data row1 col5" >0.8546</td>
#       <td id="T_a803c_row1_col6" class="data row1 col6" >0.8544</td>
#       <td id="T_a803c_row1_col7" class="data row1 col7" >0.8555</td>
#       <td id="T_a803c_row1_col8" class="data row1 col8" >75.3540</td>
#     </tr>
#     <tr>
#       <th id="T_a803c_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_a803c_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a803c_row2_col1" class="data row2 col1" >0.9992</td>
#       <td id="T_a803c_row2_col2" class="data row2 col2" >0.9708</td>
#       <td id="T_a803c_row2_col3" class="data row2 col3" >0.8382</td>
#       <td id="T_a803c_row2_col4" class="data row2 col4" >0.7389</td>
#       <td id="T_a803c_row2_col5" class="data row2 col5" >0.7841</td>
#       <td id="T_a803c_row2_col6" class="data row2 col6" >0.7837</td>
#       <td id="T_a803c_row2_col7" class="data row2 col7" >0.7859</td>
#       <td id="T_a803c_row2_col8" class="data row2 col8" >3.0990</td>
#     </tr>
#     <tr>
#       <th id="T_a803c_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_a803c_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_a803c_row3_col1" class="data row3 col1" >0.9980</td>
#       <td id="T_a803c_row3_col2" class="data row3 col2" >0.8948</td>
#       <td id="T_a803c_row3_col3" class="data row3 col3" >0.7912</td>
#       <td id="T_a803c_row3_col4" class="data row3 col4" >0.4573</td>
#       <td id="T_a803c_row3_col5" class="data row3 col5" >0.5785</td>
#       <td id="T_a803c_row3_col6" class="data row3 col6" >0.5776</td>
#       <td id="T_a803c_row3_col7" class="data row3 col7" >0.6001</td>
#       <td id="T_a803c_row3_col8" class="data row3 col8" >13.5970</td>
#     </tr>
#     <tr>
#       <th id="T_a803c_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_a803c_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a803c_row4_col1" class="data row4 col1" >0.9950</td>
#       <td id="T_a803c_row4_col2" class="data row4 col2" >0.9803</td>
#       <td id="T_a803c_row4_col3" class="data row4 col3" >0.8676</td>
#       <td id="T_a803c_row4_col4" class="data row4 col4" >0.2400</td>
#       <td id="T_a803c_row4_col5" class="data row4 col5" >0.3750</td>
#       <td id="T_a803c_row4_col6" class="data row4 col6" >0.3733</td>
#       <td id="T_a803c_row4_col7" class="data row4 col7" >0.4540</td>
#       <td id="T_a803c_row4_col8" class="data row4 col8" >225.1950</td>
#     </tr>
#     <tr>
#       <th id="T_a803c_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_a803c_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_a803c_row5_col1" class="data row5 col1" >0.9925</td>
#       <td id="T_a803c_row5_col2" class="data row5 col2" >0.9718</td>
#       <td id="T_a803c_row5_col3" class="data row5 col3" >0.7735</td>
#       <td id="T_a803c_row5_col4" class="data row5 col4" >0.1566</td>
#       <td id="T_a803c_row5_col5" class="data row5 col5" >0.2603</td>
#       <td id="T_a803c_row5_col6" class="data row5 col6" >0.2582</td>
#       <td id="T_a803c_row5_col7" class="data row5 col7" >0.3458</td>
#       <td id="T_a803c_row5_col8" class="data row5 col8" >0.2080</td>
#     </tr>
#     <tr>
#       <th id="T_a803c_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_a803c_row6_col0" class="data row6 col0" >Ada Boo

# %%
# Tunando a et classifier
extra_tree_tuned = tune_model(avaliacao, n_iter=50)
# Out:
# <style type="text/css">
# #T_c7e04_row10_col0, #T_c7e04_row10_col1, #T_c7e04_row10_col2, #T_c7e04_row10_col3, #T_c7e04_row10_col4, #T_c7e04_row10_col5, #T_c7e04_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c7e04_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7e04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7e04_row0_col0" class="data row0 col0" >0.9993</td>
#       <td id="T_c7e04_row0_col1" class="data row0 col1" >0.9929</td>
#       <td id="T_c7e04_row0_col2" class="data row0 col2" >0.9118</td>
#       <td id="T_c7e04_row0_col3" class="data row0 col3" >0.7561</td>
#       <td id="T_c7e04_row0_col4" class="data row0 col4" >0.8267</td>
#       <td id="T_c7e04_row0_col5" class="data row0 col5" >0.8263</td>
#       <td id="T_c7e04_row0_col6" class="data row0 col6" >0.8300</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7e04_row1_col0" class="data row1 col0" >0.9990</td>
#       <td id="T_c7e04_row1_col1" class="data row1 col1" >0.9725</td>
#       <td id="T_c7e04_row1_col2" class="data row1 col2" >0.8235</td>
#       <td id="T_c7e04_row1_col3" class="data row1 col3" >0.6829</td>
#       <td id="T_c7e04_row1_col4" class="data row1 col4" >0.7467</td>
#       <td id="T_c7e04_row1_col5" class="data row1 col5" >0.7462</td>
#       <td id="T_c7e04_row1_col6" class="data row1 col6" >0.7495</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7e04_row2_col0" class="data row2 col0" >0.9990</td>
#       <td id="T_c7e04_row2_col1" class="data row2 col1" >0.9829</td>
#       <td id="T_c7e04_row2_col2" class="data row2 col2" >0.7941</td>
#       <td id="T_c7e04_row2_col3" class="data row2 col3" >0.6923</td>
#       <td id="T_c7e04_row2_col4" class="data row2 col4" >0.7397</td>
#       <td id="T_c7e04_row2_col5" class="data row2 col5" >0.7393</td>
#       <td id="T_c7e04_row2_col6" class="data row2 col6" >0.7410</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7e04_row3_col0" class="data row3 col0" >0.9994</td>
#       <td id="T_c7e04_row3_col1" class="data row3 col1" >0.9866</td>
#       <td id="T_c7e04_row3_col2" class="data row3 col2" >0.8235</td>
#       <td id="T_c7e04_row3_col3" class="data row3 col3" >0.8235</td>
#       <td id="T_c7e04_row3_col4" class="data row3 col4" >0.8235</td>
#       <td id="T_c7e04_row3_col5" class="data row3 col5" >0.8232</td>
#       <td id="T_c7e04_row3_col6" class="data row3 col6" >0.8232</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7e04_row4_col0" class="data row4 col0" >0.9993</td>
#       <td id="T_c7e04_row4_col1" class="data row4 col1" >0.9731</td>
#       <td id="T_c7e04_row4_col2" class="data row4 col2" >0.8529</td>
#       <td id="T_c7e04_row4_col3" class="data row4 col3" >0.7838</td>
#       <td id="T_c7e04_row4_col4" class="data row4 col4" >0.8169</td>
#       <td id="T_c7e04_row4_col5" class="data row4 col5" >0.8166</td>
#       <td id="T_c7e04_row4_col6" class="data row4 col6" >0.8173</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7e04_row5_col0" class="data row5 col0" >0.9993</td>
#       <td id="T_c7e04_row5_col1" class="data row5 col1" >0.9731</td>
#       <td id="T_c7e04_row5_col2" class="data row5 col2" >0.7647</td>
#       <td id="T_c7e04_row5_col3" class="data row5 col3" >0.8125</td>
#       <td id="T_c7e04_row5_col4" class="data row5 col4" >0.7879</td>
#       <td id="T_c7e04_row5_col5" class="data row5 col5" >0.7875</td>
#       <td id="T_c7e04_row5_col6" class="data row5 col6" >0.7879</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7e04_row6_col0" class="data row6 col0" >0.9992</td>
#       <td id="T_c7e04_row6_col1" class="data row6 col1" >0.9778</td>
#       <td id="T_c7e04_row6_col2" class="data row6 col2" >0.8529</td>
#       <td id="T_c7e04_row6_col3" class="data row6 col3" >0.7436</td>
#       <td id="T_c7e04_row6_col4" class="data row6 col4" >0.7945</td>
#       <td id="T_c7e04_row6_col5" class="data row6 col5" >0.7941</td>
#       <td id="T_c7e04_row6_col6" class="data row6 col6" >0.7960</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7e04_row7_col0" class="data row7 col0" >0.9994</td>
#       <td id="T_c7e04_row7_col1" class="data row7 col1" >0.9900</td>
#       <td id="T_c7e04_row7_col2" class="data row7 col2" >0.9412</td>
#       <td id="T_c7e04_row7_col3" class="data row7 col3" >0.7619</td>
#       <td id="T_c7e04_row7_col4" class="data row7 col4" >0.8421</td>
#       <td id="T_c7e04_row7_col5" class="data row7 col5" >0.8418</td>
#       <td id="T_c7e04_row7_col6" class="data row7 col6" >0.8465</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7e04_row8_col0" class="data row8 col0" >0.9993</td>
#       <td id="T_c7e04_row8_col1" class="data row8 col1" >0.9680</td>
#       <td id="T_c7e04_row8_col2" class="data row8 col2" >0.7647</td>
#       <td id="T_c7e04_row8_col3" class="data row8 col3" >0.8387</td>
#       <td id="T_c7e04_row8_col4" class="data row8 col4" >0.8000</td>
#       <td id="T_c7e04_row8_col5" class="data row8 col5" >0.7997</td>
#       <td id="T_c7e04_row8_col6" class="data row8 col6" >0.8005</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7e04_row9_col0" class="data row9 col0" >0.9991</td>
#       <td id="T_c7e04_row9_col1" class="data row9 col1" >0.9966</td>
#       <td id="T_c7e04_row9_col2" class="data row9 col2" >0.8529</td>
#       <td id="T_c7e04_row9_col3" class="data row9 col3" >0.6905</td>
#       <td id="T_c7e04_row9_col4" class="data row9 col4" >0.7632</td>
#       <td id="T_c7e04_row9_col5" class="data row9 col5" >0.7627</td>
#       <td id="T_c7e04_row9_col6" class="data row9 col6" >0.7670</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c7e04_row10_col0" class="data row10 col0" >0.9993</td>
#       <td id="T_c7e04_row10_col1" class="data row10 col1" >0.9814</td>
#       <td id="T_c7e04_row10_col2" class="data row10 col2" >0.8382</td>
#       <td id="T_c7e04_row10_col3" class="data row10 col3" >0.7586</td>
#       <td id="T_c7e04_row10_col4" class="data row10 col4" >0.7941</td>
#       <td id="T_c7e04_row10_col5" class="data row10 col5" >0.7937</td>
#       <td id="T_c7e04_row10_col6" class="data row10 col6" >0.7959</td>
#     </tr>
#     <tr>
#       <th id="T_c7e04_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c7e04_row11_col0" class="data row11 col0" >0.0001</td>
#       <td id="T_c7e04_row11_col1" class="data row11 col1" >0.0094</td>
#       <td id="T_c7e04_row11_col2" class="data row11 col2" >0.0546</td>
#       <td id="T_c7e04_row11_col3" class="data row11 col3" >0.0540</td>
#       <td id="T_c7e04_row11_col4" class="data row11 col4" >0.0331</td>
#       <td id="T_c7e04_row11_col5" class="data row11 col5" >0.0332</td>
#       <td id="T_c7e04_row11_col6" class="data row11 col6" >0.033

# %%
# Teste com ET
# modelo = create_model('et')
predict_model(avaliacao, data = df);
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f174_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f174_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f174_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_2f174_row0_col1" class="data row0 col1" >0.9998</td>
#       <td id="T_2f174_row0_col2" class="data row0 col2" >0.9892</td>
#       <td id="T_2f174_row0_col3" class="data row0 col3" >0.9390</td>
#       <td id="T_2f174_row0_col4" class="data row0 col4" >0.9726</td>
#       <td id="T_2f174_row0_col5" class="data row0 col5" >0.9555</td>
#       <td id="T_2f174_row0_col6" class="data row0 col6" >0.9555</td>
#       <td id="T_2f174_row0_col7" class="data row0 col7" >0.9556</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Teste com ET tunado
predict_model(extra_tree_tuned, data = df);
# Out:
# <style type="text/css">
# </style>
# <table id="T_92bf4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92bf4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92bf4_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_92bf4_row0_col1" class="data row0 col1" >0.9992</td>
#       <td id="T_92bf4_row0_col2" class="data row0 col2" >0.9781</td>
#       <td id="T_92bf4_row0_col3" class="data row0 col3" >0.8252</td>
#       <td id="T_92bf4_row0_col4" class="data row0 col4" >0.7505</td>
#       <td id="T_92bf4_row0_col5" class="data row0 col5" >0.7861</td>
#       <td id="T_92bf4_row0_col6" class="data row0 col6" >0.7857</td>
#       <td id="T_92bf4_row0_col7" class="data row0 col7" >0.7866</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5 - Treinando e salvando modelo

# %% [markdown]
# *   Foi escolhido Extra Tree Classifier por melhor desempenho, sem opção de bagging.

# %%
modelo_final = finalize_model(avaliacao)
save_model(modelo_final, './et_fraudscore_v1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Class',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=2,
#                                        oob_score=False, random_state=2456,
#                                        verbose=0, warm_start=False)]],
#           verbose=False),
#  './et_fraudscore_v1.pkl')
